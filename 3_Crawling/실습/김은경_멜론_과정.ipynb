# %% [markdown]
# # 과정

# %%
import requests
from bs4 import BeautifulSoup

# %%
# status_code 406 나와서 코드 추가

request_headers = {
    'User-Agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 '
                   '(KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36')
}

# %%
response = requests.get('https://www.melon.com/chart/index.htm', headers = request_headers)
# status_code 확인하기!!(그래야 막혔는지 안막혔는지, 데이터 잘 받아올 수 있는지 확인 가능!)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'lxml')
infos = soup.select('tr[class=lst50]') # 'div[class=tit3]'
lists = []
for info in infos:
    lists.append(info.text.strip())

# %%
def crawling():
    import requests
    from bs4 import BeautifulSoup
    request_headers = {'User-Agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 '
                   '(KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36')}
    response = requests.get('https://www.melon.com/chart/index.htm', headers = request_headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'lxml')
        song_infos1 = soup.select('tr[class=lst50]')
        song_infos2 = soup.select('tr[class=lst100]')
        song_infos = song_infos1 + song_infos2
    return song_infos

# %%
crawling()
# Out:
# [<tr class="lst50" data-song-no="34819473" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="사건의 지평선 곡 선택" type="checkbox" value="34819473"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10903868');" title="YOUNHA 6th Album Repackage 'END THEORY : Final Edition'">
#  <img alt="YOUNHA 6th Album Repackage 'END THEORY : Final Edition' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/109/03/868/10903868_20220330103544_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('34819473');" title="사건의 지평선 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',34819473);" title="사건의 지평선 재생">사건의 지평선</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('203912');" title="윤하 (YOUNHA) - 페이지 이동">윤하 (YOUNHA)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('203912');" title="윤하 (YOUNHA) - 페이지 이동">윤하 (YOUNHA)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10903868');" title="YOUNHA 6th Album Repackage 'END THEORY : Final Edition' - 페이지 이동">YOUNHA 6th Album Repackage 'END THEORY : Final Edition'</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="34819473" title="사건의 지평선 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',34819473);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('34819473');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '34819473', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '34819473','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35729104" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="ANTIFRAGILE 곡 선택" type="checkbox" value="35729104"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">2</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11078496');" title="ANTIFRAGILE">
#  <img alt="ANTIFRAGILE - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/78/496/11078496_20221014153848_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35729104');" title="ANTIFRAGILE 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35729104);" title="ANTIFRAGILE 재생">ANTIFRAGILE</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('3092950');" title="LE SSERAFIM (르세라핌) - 페이지 이동">LE SSERAFIM (르세라핌)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3092950');" title="LE SSERAFIM (르세라핌) - 페이지 이동">LE SSERAFIM (르세라핌)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11078496');" title="ANTIFRAGILE - 페이지 이동">ANTIFRAGILE</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35729104" title="ANTIFRAGILE 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35729104);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35729104');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35729104', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35729104','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35730562" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Nxde 곡 선택" type="checkbox" value="35730562"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">3</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11078852');" title="I love">
#  <img alt="I love - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/78/852/11078852_20221017102947_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35730562');" title="Nxde 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35730562);" title="Nxde 재생">Nxde</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('2137482');" title="(여자)아이들 - 페이지 이동">(여자)아이들</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2137482');" title="(여자)아이들 - 페이지 이동">(여자)아이들</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11078852');" title="I love - 페이지 이동">I love</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35730562" title="Nxde 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35730562);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35730562');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35730562', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35730562','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35454426" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Hype boy 곡 선택" type="checkbox" value="35454426"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">4</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11011565');" title="NewJeans 1st EP 'New Jeans'">
#  <img alt="NewJeans 1st EP 'New Jeans' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/11/565/11011565_20220801102637_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35454426');" title="Hype boy 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35454426);" title="Hype boy 재생">Hype boy</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11011565');" title="NewJeans 1st EP 'New Jeans' - 페이지 이동">NewJeans 1st EP 'New Jeans'</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35454426" title="Hype boy 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35454426);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35454426');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35454426', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35454426','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35546497" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="After LIKE 곡 선택" type="checkbox" value="35546497"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">5</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11034298');" title="After LIKE">
#  <img alt="After LIKE - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/34/298/11034298_20220822101843_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35546497');" title="After LIKE 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35546497);" title="After LIKE 재생">After LIKE</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11034298');" title="After LIKE - 페이지 이동">After LIKE</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35546497" title="After LIKE 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35546497);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35546497');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35546497', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35546497','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="34061322" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="사랑은 늘 도망가 곡 선택" type="checkbox" value="34061322"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">6</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="1단계 상승">
#  <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
#  <span class="up">1</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10735654');" title="신사와 아가씨 OST Part.2">
#  <img alt="신사와 아가씨 OST Part.2 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/107/35/654/10735654_20211008114339_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('34061322');" title="사랑은 늘 도망가 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',34061322);" title="사랑은 늘 도망가 재생">사랑은 늘 도망가</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10735654');" title="신사와 아가씨 OST Part.2 - 페이지 이동">신사와 아가씨 OST Part.2</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="34061322" title="사랑은 늘 도망가 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',34061322);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('34061322');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '34061322', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '34061322','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35834583" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="London Boy 곡 선택" type="checkbox" value="35834583"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">7</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="7단계 상승">
#  <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
#  <span class="up">7</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11102375');" title="Polaroid">
#  <img alt="Polaroid - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/111/02/375/11102375_20221115101140_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35834583');" title="London Boy 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35834583);" title="London Boy 재생">London Boy</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11102375');" title="Polaroid - 페이지 이동">Polaroid</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35834583" title="London Boy 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35834583);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35834583');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35834583', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35834583','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35595136" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="새삥 (Prod. ZICO) (Feat. 호미들) 곡 선택" type="checkbox" value="35595136"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">8</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="2단계 하락">
#  <span class="bullet_icons rank_down"><span class="none">단계 하락</span></span>
#  <span class="down">2</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11045985');" title="스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)">
#  <img alt="스트릿 맨 파이터(SMF) Original Vol.3 (계급미션) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/45/985/11045985_20220905151107_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35595136');" title="새삥 (Prod. ZICO) (Feat. 호미들) 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35595136);" title="새삥 (Prod. ZICO) (Feat. 호미들) 재생">새삥 (Prod. ZICO) (Feat. 호미들)</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('602056');" title="지코 (ZICO) - 페이지 이동">지코 (ZICO)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('602056');" title="지코 (ZICO) - 페이지 이동">지코 (ZICO)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11045985');" title="스트릿 맨 파이터(SMF) Original Vol.3 (계급미션) - 페이지 이동">스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35595136" title="새삥 (Prod. ZICO) (Feat. 호미들) 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35595136);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35595136');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35595136', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '35595136','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="34908740" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="우리들의 블루스 곡 선택" type="checkbox" value="34908740"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">9</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="1단계 상승">
#  <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
#  <span class="up">1</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10923444');" title="IM HERO">
#  <img alt="IM HERO - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/109/23/444/10923444_20220502140600_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('34908740');" title="우리들의 블루스 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',34908740);" title="우리들의 블루스 재생">우리들의 블루스</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10923444');" title="IM HERO - 페이지 이동">IM HERO</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="34908740" title="우리들의 블루스 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',34908740);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('34908740');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '34908740', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '34908740','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35834584" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Polaroid 곡 선택" type="checkbox" value="35834584"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">10</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="7단계 상승">
#  <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
#  <span class="up">7</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11102375');" title="Polaroid">
#  <img alt="Polaroid - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/111/02/375/11102375_20221115101140_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35834584');" title="Polaroid 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35834584);" title="Polaroid 재생">Polaroid</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11102375');" title="Polaroid - 페이지 이동">Polaroid</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35834584" title="Polaroid 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35834584);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35834584');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35834584', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35834584','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35008524" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="다시 만날 수 있을까 곡 선택" type="checkbox" value="35008524"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">11</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="1단계 상승">
#  <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
#  <span class="up">1</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10923444');" title="IM HERO">
#  <img alt="IM HERO - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/109/23/444/10923444_20220502140600_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35008524');" title="다시 만날 수 있을까 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35008524);" title="다시 만날 수 있을까 재생">다시 만날 수 있을까</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10923444');" title="IM HERO - 페이지 이동">IM HERO</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35008524" title="다시 만날 수 있을까 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35008524);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35008524');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35008524', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35008524','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35665282" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Rush Hour (Feat. j-hope of BTS) 곡 선택" type="checkbox" value="35665282"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">12</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="4단계 하락">
#  <span class="bullet_icons rank_down"><span class="none">단계 하락</span></span>
#  <span class="down">4</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11062364');" title="Rush Hour">
#  <img alt="Rush Hour - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/62/364/11062364_20220922182518_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35665282');" title="Rush Hour (Feat. j-hope of BTS) 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35665282);" title="Rush Hour (Feat. j-hope of BTS) 재생">Rush Hour (Feat. j-hope of BTS)</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('674710');" title="Crush - 페이지 이동">Crush</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('674710');" title="Crush - 페이지 이동">Crush</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11062364');" title="Rush Hour - 페이지 이동">Rush Hour</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35665282" title="Rush Hour (Feat. j-hope of BTS) 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35665282);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35665282');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35665282', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35665282','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35454425" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Attention 곡 선택" type="checkbox" value="35454425"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">13</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="4단계 하락">
#  <span class="bullet_icons rank_down"><span class="none">단계 하락</span></span>
#  <span class="down">4</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11011565');" title="NewJeans 1st EP 'New Jeans'">
#  <img alt="NewJeans 1st EP 'New Jeans' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/11/565/11011565_20220801102637_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35454425');" title="Attention 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35454425);" title="Attention 재생">Attention</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11011565');" title="NewJeans 1st EP 'New Jeans' - 페이지 이동">NewJeans 1st EP 'New Jeans'</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35454425" title="Attention 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35454425);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35454425');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35454425', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35454425','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35008525" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="무지개 곡 선택" type="checkbox" value="35008525"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">14</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="2단계 상승">
#  <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
#  <span class="up">2</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10923444');" title="IM HERO">
#  <img alt="IM HERO - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/109/23/444/10923444_20220502140600_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35008525');" title="무지개 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35008525);" title="무지개 재생">무지개</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10923444');" title="IM HERO - 페이지 이동">IM HERO</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35008525" title="무지개 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35008525);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35008525');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35008525', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '35008525','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="32508053" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="이제 나만 믿어요 곡 선택" type="checkbox" value="32508053"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">15</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="3단계 상승">
#  <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
#  <span class="up">3</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10412319');" title="내일은 미스터트롯 우승자 특전곡">
#  <img alt="내일은 미스터트롯 우승자 특전곡 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/104/12/319/10412319_20200403103006_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('32508053');" title="이제 나만 믿어요 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',32508053);" title="이제 나만 믿어요 재생">이제 나만 믿어요</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10412319');" title="내일은 미스터트롯 우승자 특전곡 - 페이지 이동">내일은 미스터트롯 우승자 특전곡</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="32508053" title="이제 나만 믿어요 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',32508053);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('32508053');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '32508053', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '32508053','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35008527" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="아버지 곡 선택" type="checkbox" value="35008527"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">16</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="3단계 상승">
#  <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
#  <span class="up">3</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10923444');" title="IM HERO">
#  <img alt="IM HERO - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/109/23/444/10923444_20220502140600_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35008527');" title="아버지 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35008527);" title="아버지 재생">아버지</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10923444');" title="IM HERO - 페이지 이동">IM HERO</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35008527" title="아버지 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35008527);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
# ...
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35694868);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35694868');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35694868', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35694868','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst100" data-song-no="35177030" id="lst100">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="늦은 밤 헤어지긴 너무 아쉬워 곡 선택" type="checkbox" value="35177030"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">96</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="2단계 하락">
#  <span class="bullet_icons rank_down"><span class="none">단계 하락</span></span>
#  <span class="down">2</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10960568');" title="LOVE &amp; HATE">
#  <img alt="LOVE &amp; HATE - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/109/60/568/10960568_20220518153132_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35177030');" title="늦은 밤 헤어지긴 너무 아쉬워 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35177030);" title="늦은 밤 헤어지긴 너무 아쉬워 재생">늦은 밤 헤어지긴 너무 아쉬워</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('858125');" title="케이시 (Kassy) - 페이지 이동">케이시 (Kassy)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('858125');" title="케이시 (Kassy) - 페이지 이동">케이시 (Kassy)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10960568');" title="LOVE &amp; HATE - 페이지 이동">LOVE &amp; HATE</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35177030" title="늦은 밤 헤어지긴 너무 아쉬워 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35177030);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35177030');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35177030', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35177030','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst100" data-song-no="35307770" id="lst100">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="빛이 나는 사람 곡 선택" type="checkbox" value="35307770"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">97</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 진입">
#  <span class="bullet_icons rank_new"><span class="none">순위 진입</span></span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10985673');" title="빛이 나는 사람">
#  <img alt="빛이 나는 사람 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/109/85/673/10985673_20220617143044_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35307770');" title="빛이 나는 사람 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35307770);" title="빛이 나는 사람 재생">빛이 나는 사람</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('720018');" title="김호중 - 페이지 이동">김호중</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('720018');" title="김호중 - 페이지 이동">김호중</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10985673');" title="빛이 나는 사람 - 페이지 이동">빛이 나는 사람</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35307770" title="빛이 나는 사람 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35307770);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35307770');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35307770', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '35307770','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst100" data-song-no="35466605" id="lst100">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="약속 [約束] 곡 선택" type="checkbox" value="35466605"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">98</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 진입">
#  <span class="bullet_icons rank_new"><span class="none">순위 진입</span></span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11014554');" title="PANORAMA">
#  <img alt="PANORAMA - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/14/554/11014554_20220726174229_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35466605');" title="약속 [約束] 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35466605);" title="약속 [約束] 재생">약속 [約束]</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('720018');" title="김호중 - 페이지 이동">김호중</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('720018');" title="김호중 - 페이지 이동">김호중</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11014554');" title="PANORAMA - 페이지 이동">PANORAMA</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35466605" title="약속 [約束] 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35466605);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35466605');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35466605', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35466605','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst100" data-song-no="35466597" id="lst100">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="친구 곡 선택" type="checkbox" value="35466597"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">99</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 진입">
#  <span class="bullet_icons rank_new"><span class="none">순위 진입</span></span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11014554');" title="PANORAMA">
#  <img alt="PANORAMA - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/14/554/11014554_20220726174229_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35466597');" title="친구 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35466597);" title="친구 재생">친구</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('720018');" title="김호중 - 페이지 이동">김호중</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('720018');" title="김호중 - 페이지 이동">김호중</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11014554');" title="PANORAMA - 페이지 이동">PANORAMA</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35466597" title="친구 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35466597);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35466597');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35466597', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '35466597','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst100" data-song-no="33978183" id="lst100">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="너를 생각해 곡 선택" type="checkbox" value="33978183"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">100</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="4단계 하락">
#  <span class="bullet_icons rank_down"><span class="none">단계 하락</span></span>
#  <span class="down">4</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10716399');" title="너를 생각해">
#  <img alt="너를 생각해 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/107/16/399/10716399_20210916173429_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('33978183');" title="너를 생각해 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',33978183);" title="너를 생각해 재생">너를 생각해</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('2880487');" title="주시크 (Joosiq) - 페이지 이동">주시크 (Joosiq)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2880487');" title="주시크 (Joosiq) - 페이지 이동">주시크 (Joosiq)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10716399');" title="너를 생각해 - 페이지 이동">너를 생각해</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="33978183" title="너를 생각해 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',33978183);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('33978183');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '33978183', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '33978183','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>]

# %%
! pip install bs4 html5lib lxml chardet
# Out:
# Requirement already satisfied: bs4 in c:\users\user\.venv\second_day\lib\site-packages (0.0.1)
# Requirement already satisfied: html5lib in c:\users\user\.venv\second_day\lib\site-packages (1.1)
# Requirement already satisfied: lxml in c:\users\user\.venv\second_day\lib\site-packages (4.9.1)
# Requirement already satisfied: chardet in c:\users\user\.venv\second_day\lib\site-packages (5.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\.venv\second_day\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: six>=1.9 in c:\users\user\.venv\second_day\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\user\.venv\second_day\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\.venv\second_day\lib\site-packages (from beautifulsoup4->bs4) (2.3.2.post1)

# %%
def crawling():
    import requests
    from bs4 import BeautifulSoup
    request_headers = {'User-Agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 '
                   '(KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36')}
    response = requests.get('https://www.melon.com/chart/index.htm', headers = request_headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'lxml')
        song_infos1 = soup.select('tr[class=lst50]')
        song_infos2 = soup.select('tr[class=lst100]')
        song_infos = song_infos1 + song_infos2
        
        chart_lst = []
        
        for song_info in song_infos:
            info_lst = [] # 한 곡의 정보
            
            # 순위
            ranking = song_info.select('span.rank')[0].text # 'span.rank' / 'span[class=rank]' 다됨!!  / tag=span, class=rank(.) / id는(#)
            info_lst.append(ranking)
            # 가수
            singer = song_info.select('div.ellipsis.rank02 >a')[0].text
            info_lst.append(singer)
            # 노래 제목
            title = song_info.select('div.ellipsis.rank01 > span > a')[0].text
            info_lst.append(title)
            # 앨범
            album = song_info.select('div.ellipsis.rank03 > a')[0].text
            info_lst.append(album)
            # 좋아요 수
            like = song_info.select('span.cnt > span.none')[0].text
            info_lst.append(like)
            
            chart_lst.append(info_lst)
    return chart_lst

# %%
crawling()
# Out:
# [['1',
#   '윤하 (YOUNHA)',
#   '사건의 지평선',
#   "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'",
#   '총건수'],
#  ['2', 'LE SSERAFIM (르세라핌)', 'ANTIFRAGILE', 'ANTIFRAGILE', '총건수'],
#  ['3', '(여자)아이들', 'Nxde', 'I love', '총건수'],
#  ['4', '임영웅', '사랑은 늘 도망가', '신사와 아가씨 OST Part.2', '총건수'],
#  ['5', 'NewJeans', 'Hype boy', "NewJeans 1st EP 'New Jeans'", '총건수'],
#  ['6', '임영웅', 'London Boy', 'Polaroid', '총건수'],
#  ['7', '임영웅', '우리들의 블루스', 'IM HERO', '총건수'],
#  ['8', '임영웅', 'Polaroid', 'Polaroid', '총건수'],
#  ['9', '임영웅', '다시 만날 수 있을까', 'IM HERO', '총건수'],
#  ['10', 'IVE (아이브)', 'After LIKE', 'After LIKE', '총건수'],
#  ['11', '임영웅', '무지개', 'IM HERO', '총건수'],
#  ['12', '임영웅', '이제 나만 믿어요', '내일은 미스터트롯 우승자 특전곡', '총건수'],
#  ['13', '임영웅', '아버지', 'IM HERO', '총건수'],
#  ['14', '임영웅', 'A bientot', 'IM HERO', '총건수'],
#  ['15',
#   '지코 (ZICO)',
#   '새삥 (Prod. ZICO) (Feat. 호미들)',
#   '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   '총건수'],
#  ['16', '임영웅', '손이 참 곱던 그대', 'IM HERO', '총건수'],
#  ['17', '임영웅', '인생찬가', 'IM HERO', '총건수'],
#  ['18', '임영웅', '사랑해 진짜', 'IM HERO', '총건수'],
#  ['19', '임영웅', '연애편지', 'IM HERO', '총건수'],
#  ['20', 'Crush', 'Rush Hour (Feat. j-hope of BTS)', 'Rush Hour', '총건수'],
#  ['21', 'NewJeans', 'Attention', "NewJeans 1st EP 'New Jeans'", '총건수'],
#  ['22', '임영웅', '보금자리', 'IM HERO', '총건수'],
#  ['23', '테이', 'Monologue', 'Monologue', '총건수'],
#  ['24', 'IVE (아이브)', 'LOVE DIVE', 'LOVE DIVE', '총건수'],
#  ['25', 'BLACKPINK', 'Shut Down', 'BORN PINK', '총건수'],
#  ['26', "BE'O (비오)", '자격지심 (Feat. ZICO)', 'FIVE SENSES', '총건수'],
#  ['27', 'BLACKPINK', 'Pink Venom', 'BORN PINK', '총건수'],
#  ['28', '#안녕', '해요 (2022)', '해요 (2022)', '총건수'],
#  ['29', '10CM', '딱 10CM만', '딱 10CM만', '총건수'],
#  ['30', '(여자)아이들', 'TOMBOY', 'I NEVER DIE', '총건수'],
#  ['31', '주호', '내가 아니라도', '내가 아니라도', '총건수'],
#  ['32', 'WSG워너비 (가야G)', '그때 그 순간 그대로 (그그그)', 'WSG워너비 1집', '총건수'],
#  ['33', '10CM', '그라데이션', '5.3', '총건수'],
#  ['34', '멜로망스', '사랑인가 봐', '사랑인가 봐 (사내맞선 OST 스페셜 트랙)', '총건수'],
#  ['35', '강민경 (다비치)', '우린 그렇게 사랑해서', '우린 그렇게 사랑해서', '총건수'],
#  ['36', 'NewJeans', 'Cookie', "NewJeans 1st EP 'New Jeans'", '총건수'],
#  ['37', '성시경', '너의 모든 순간', '별에서 온 그대 OST Part.7', '총건수'],
#  ['38', 'LE SSERAFIM (르세라핌)', 'FEARLESS', 'FEARLESS', '총건수'],
#  ['39', 'BIG Naughty (서동현)', '정이라고 하자 (Feat. 10CM)', '정이라고 하자', '총건수'],
#  ['40', '백아', '첫사랑', '첫사랑', '총건수'],
#  ['41', '임한별', '떠나보낼 준비해 둘걸 그랬어', '떠나보낼 준비해 둘걸 그랬어', '총건수'],
#  ['42',
#   '정국',
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)',
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack]',
#   '총건수'],
#  ['43', '싸이 (PSY)', 'That That (prod. & feat. SUGA of BTS)', '싸다9', '총건수'],
#  ['44', '경서', '나의 X에게', '나의 X에게', '총건수'],
#  ['45', '방탄소년단', 'Dynamite', 'Dynamite (DayTime Version)', '총건수'],
#  ['46', 'IVE (아이브)', 'ELEVEN', 'ELEVEN', '총건수'],
#  ['47', '김민석 (멜로망스)', '취중고백', '취중고백', '총건수'],
#  ['48', '진', 'The Astronaut', 'The Astronaut', '총건수'],
#  ['49', '김호중', '그중에 그대를 만나', '삼남매가 용감하게 OST Part.1', '총건수'],
#  ['50', 'WSG워너비 (4FIRE)', '보고싶었어', 'WSG워너비 1집', '총건수'],
#  ['51',
#   'Charlie Puth',
#   'Left and Right (Feat. Jung Kook of BTS)',
#   'Left and Right (Feat. Jung Kook of BTS)',
#   '총건수'],
#  ['52', 'Charlie Puth', "That's Hilarious", 'CHARLIE', '총건수'],
#  ['53', '김호중', '나의 목소리로', '나의 목소리로', '총건수'],
#  ['54', '경서예지', '다정히 내 이름을 부르면', '다정히 내 이름을 부르면 (경서예지 x 전건호)', '총건수'],
#  ['55', '김승민', '내 기쁨은 너가 벤틀리를 끄는 거야', 'PROTOTYPE RESEARCH #0063', '총건수'],
#  ['56', '방탄소년단', 'Butter', 'Butter', '총건수'],
#  ['57', '방탄소년단', 'Yet To Come', 'Proof', '총건수'],
#  ['58', 'Charlie Puth', "I Don't Think That I Like Her", 'CHARLIE', '총건수'],
#  ['59', '방탄소년단', '봄날', 'YOU NEVER WALK ALONE', '총건수'],
#  ['60', "BE'O (비오)", 'LOVE me', 'LOVE me', '총건수'],
#  ['61', '김호중', '인생은 뷰티풀', '인생은 뷰티풀: 비타돌체', '총건수'],
#  ['62', '잔나비', '주저하는 연인들을 위해', '전설', '총건수'],
#  ['63', '경서', '고백연습', '고백연습', '총건수'],
#  ['64',
#   "소녀시대 (GIRLS' GENERATION)",
#   'FOREVER 1',
#   'FOREVER 1 - The 7th Album',
#   '총건수'],
#  ['65', '방탄소년단', 'Permission to Dance', 'Butter / Permission to Dance', '총건수'],
#  ['66', '한동근', '새벽에 걸려온 너의 전화는', '미련을 말하는', '총건수'],
#  ['67',
#   '폴킴',
#   '모든 날, 모든 순간 (Every day, Every Moment)',
#   "'키스 먼저 할까요?' OST Part.3",
#   '총건수'],
#  ['68', 'aespa', '도깨비불 (Illusion)', 'Girls - The 2nd Mini Album', '총건수'],
#  ['69', '볼빨간사춘기', 'Love story', 'Seoul', '총건수'],
#  ['70', '김호중', '주마등', 'PANORAMA', '총건수'],
#  ['71', 'The Kid LAROI', 'STAY', 'Stay', '총건수'],
#  ['72', 'ITZY (있지)', 'SNEAKERS', 'CHECKMATE', '총건수'],
#  ['73', '탑현', '사랑한다고 말해줘', '사랑한다고 말해줘', '총건수'],
#  ['74', '경서', '밤하늘의 별을(2020)', '밤하늘의 별을(2020)', '총건수'],
#  ['75', '김호중', '빛이 나는 사람', '빛이 나는 사람', '총건수'],
#  ['76', 'BIGBANG (빅뱅)', '봄여름가을겨울 (Still Life)', '봄여름가을겨울 (Still Life)', '총건수'],
#  ['77', '김호중', '약속 [約束]', 'PANORAMA', '총건수'],
#  ['78', '김호중', '친구', 'PANORAMA', '총건수'],
#  ['79', '김호중', '슬픈등', '인생은 뷰티풀: 비타돌체', '총건수'],
#  ['80',
#   '윤미래',
#   'LAW (Prod. Czaer)',
#   '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   '총건수'],
#  ['81', '김호중', 'Brucia La Terra', 'PANORAMA', '총건수'],
#  ['82', '김호중', 'Champagne', 'PANORAMA', '총건수'],
#  ['83', '나연 (TWICE)', 'POP!', 'IM NAYEON', '총건수'],
#  ['84', '김호중', 'Love in Portofino', 'PANORAMA', '총건수'],
#  ['85', '21학번', '스티커 사진', '스티커 사진', '총건수'],
#  ['86',
#   'Red Velvet (레드벨벳)',
#   'Feel My Rhythm',
#   '‘The ReVe Festival 2022 - Feel My Rhythm’',
#   '총건수'],
#  ['87', '태연 (TAEYEON)', 'INVU', 'INVU - The 3rd Album', '총건수'],
#  ['88', '김호중', '노래해요 (Duet with 최백호)', 'PANORAMA', '총건수'],
#  ['89', '(여자)아이들', 'MY BAG', 'I NEVER DIE', '총건수'],
#  ['90', '아이유', 'strawberry moon', 'strawberry moon', '총건수'],
#  ['91', '아이유', '내 손을 잡아', '최고의 사랑 OST Part.4', '총건수'],
#  ['92',
#   'Justin Bieber',
#   'Off My Face',
#   'Justice (The Complete Edition)',
#   '총건수'],
#  ['93', '이영현', '그래서 그대는', '그래서 그대는', '총건수'],
#  ['94', 'NMIXX', 'DICE', 'ENTWURF', '총건수'],
#  ['95', '이무진', '신호등', '신호등', '총건수'],
#  ['96', 'aespa', 'Next Level', 'Next Level', '총건수'],
#  ['97', '윤하 (YOUNHA)', '오르트구름', "YOUNHA 6th Album 'END THEORY'", '총건수'],
#  ['98', '보라미유', '통화연결음', '통화연결음', '총건수'],
#  ['99', '아이유', '드라마', '조각집', '총건수'],
#  ['100', '김나영', '못해', '못해 (Re : WIND 4MEN Vol.02)', '총건수']]

# %%
def crawling():
    import requests
    from bs4 import BeautifulSoup
    request_headers = {'User-Agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 '
                   '(KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36')}
    response = requests.get('https://www.melon.com/chart/index.htm', headers = request_headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'lxml')
        song_infos1 = soup.select('tr[class=lst50]')
        song_infos2 = soup.select('tr[class=lst100]')
        song_infos = song_infos1 + song_infos2
        
        chart_lst = []
        
        for song_info in song_infos:
            
            # 순위
            ranking = song_info.select('span.rank')[0].text # 'span.rank' / 'span[class=rank]' 다됨!!  / tag=span, class=rank(.) / id는(#)
            # 가수
            singer = song_info.select('div.ellipsis.rank02 >a')[0].text
            # 노래 제목
            title = song_info.select('div.ellipsis.rank01 > span > a')[0].text
            # 앨범
            album = song_info.select('div.ellipsis.rank03 > a')[0].text
            # # 좋아요 수 - 숫자가 잘 안 나오네요..ㅎ
            # like = song_info.select('span.cnt')[0].text
        
            chart_lst.append([ranking, singer, title, album]) # 한 곡의 정보가 리스트로 묶여 chart_lst 리스트 안에 들어감
            
        
    return chart_lst

# %%
crawling()
# Out:
# [['1',
#   '윤하 (YOUNHA)',
#   '사건의 지평선',
#   "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'",
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['2',
#   'LE SSERAFIM (르세라핌)',
#   'ANTIFRAGILE',
#   'ANTIFRAGILE',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['3',
#   '(여자)아이들',
#   'Nxde',
#   'I love',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['4',
#   '임영웅',
#   '사랑은 늘 도망가',
#   '신사와 아가씨 OST Part.2',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['5',
#   'NewJeans',
#   'Hype boy',
#   "NewJeans 1st EP 'New Jeans'",
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['6',
#   '임영웅',
#   'London Boy',
#   'Polaroid',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['7',
#   '임영웅',
#   '우리들의 블루스',
#   'IM HERO',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['8',
#   '임영웅',
#   'Polaroid',
#   'Polaroid',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['9',
#   '임영웅',
#   '다시 만날 수 있을까',
#   'IM HERO',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['10',
#   'IVE (아이브)',
#   'After LIKE',
#   'After LIKE',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['11',
#   '임영웅',
#   '무지개',
#   'IM HERO',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['12',
#   '임영웅',
#   '이제 나만 믿어요',
#   '내일은 미스터트롯 우승자 특전곡',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['13',
#   '임영웅',
#   '아버지',
#   'IM HERO',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['14',
#   '임영웅',
#   'A bientot',
#   'IM HERO',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['15',
#   '지코 (ZICO)',
#   '새삥 (Prod. ZICO) (Feat. 호미들)',
#   '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['16',
#   '임영웅',
#   '손이 참 곱던 그대',
#   'IM HERO',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['17',
#   '임영웅',
#   '인생찬가',
#   'IM HERO',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['18',
#   '임영웅',
#   '사랑해 진짜',
#   'IM HERO',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['19',
#   '임영웅',
#   '연애편지',
#   'IM HERO',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['20',
#   'Crush',
#   'Rush Hour (Feat. j-hope of BTS)',
#   'Rush Hour',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['21',
#   'NewJeans',
#   'Attention',
#   "NewJeans 1st EP 'New Jeans'",
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['22',
#   '임영웅',
#   '보금자리',
#   'IM HERO',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['23',
#   '테이',
#   'Monologue',
#   'Monologue',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['24',
#   'IVE (아이브)',
#   'LOVE DIVE',
#   'LOVE DIVE',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['25',
#   'BLACKPINK',
#   'Shut Down',
#   'BORN PINK',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['26',
#   "BE'O (비오)",
#   '자격지심 (Feat. ZICO)',
#   'FIVE SENSES',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['27',
#   'BLACKPINK',
#   'Pink Venom',
#   'BORN PINK',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['28',
#   '#안녕',
#   '해요 (2022)',
#   '해요 (2022)',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['29',
#   '10CM',
#   '딱 10CM만',
#   '딱 10CM만',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['30',
#   '(여자)아이들',
#   'TOMBOY',
#   'I NEVER DIE',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['31',
#   '주호',
#   '내가 아니라도',
#   '내가 아니라도',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['32',
#   'WSG워너비 (가야G)',
#   '그때 그 순간 그대로 (그그그)',
#   'WSG워너비 1집',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['33',
#   '10CM',
#   '그라데이션',
#   '5.3',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['34',
#   '멜로망스',
#   '사랑인가 봐',
#   '사랑인가 봐 (사내맞선 OST 스페셜 트랙)',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['35',
#   '강민경 (다비치)',
#   '우린 그렇게 사랑해서',
#   '우린 그렇게 사랑해서',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['36',
#   'NewJeans',
#   'Cookie',
#   "NewJeans 1st EP 'New Jeans'",
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['37',
#   '성시경',
#   '너의 모든 순간',
#   '별에서 온 그대 OST Part.7',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['38',
#   'LE SSERAFIM (르세라핌)',
#   'FEARLESS',
#   'FEARLESS',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['39',
#   'BIG Naughty (서동현)',
#   '정이라고 하자 (Feat. 10CM)',
#   '정이라고 하자',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['40',
#   '백아',
#   '첫사랑',
#   '첫사랑',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['41',
#   '임한별',
#   '떠나보낼 준비해 둘걸 그랬어',
#   '떠나보낼 준비해 둘걸 그랬어',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['42',
#   '정국',
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)',
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack]',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['43',
#   '싸이 (PSY)',
#   'That That (prod. & feat. SUGA of BTS)',
#   '싸다9',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['44',
#   '경서',
#   '나의 X에게',
#   '나의 X에게',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['45',
#   '방탄소년단',
#   'Dynamite',
#   'Dynamite (DayTime Version)',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['46',
#   'IVE (아이브)',
#   'ELEVEN',
#   'ELEVEN',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['47',
#   '김민석 (멜로망스)',
#   '취중고백',
#   '취중고백',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['48',
#   '진',
#   'The Astronaut',
#   'The Astronaut',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['49',
#   '김호중',
#   '그중에 그대를 만나',
#   '삼남매가 용감하게 OST Part.1',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['50',
#   'WSG워너비 (4FIRE)',
#   '보고싶었어',
#   'WSG워너비 1집',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['51',
#   'Charlie Puth',
#   'Left and Right (Feat. Jung Kook of BTS)',
#   'Left and Right (Feat. Jung Kook of BTS)',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['52',
#   'Charlie Puth',
#   "That's Hilarious",
#   'CHARLIE',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['53',
#   '김호중',
#   '나의 목소리로',
#   '나의 목소리로',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['54',
#   '경서예지',
#   '다정히 내 이름을 부르면',
#   '다정히 내 이름을 부르면 (경서예지 x 전건호)',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['55',
#   '김승민',
#   '내 기쁨은 너가 벤틀리를 끄는 거야',
#   'PROTOTYPE RESEARCH #0063',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['56',
#   '방탄소년단',
#   'Butter',
#   'Butter',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['57',
#   '방탄소년단',
#   'Yet To Come',
#   'Proof',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['58',
#   'Charlie Puth',
#   "I Don't Think That I Like Her",
#   'CHARLIE',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['59',
#   '방탄소년단',
#   '봄날',
#   'YOU NEVER WALK ALONE',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['60',
#   "BE'O (비오)",
#   'LOVE me',
#   'LOVE me',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['61',
#   '김호중',
#   '인생은 뷰티풀',
#   '인생은 뷰티풀: 비타돌체',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['62',
#   '잔나비',
#   '주저하는 연인들을 위해',
#   '전설',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['63',
#   '경서',
#   '고백연습',
#   '고백연습',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['64',
#   "소녀시대 (GIRLS' GENERATION)",
#   'FOREVER 1',
#   'FOREVER 1 - The 7th Album',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['65',
#   '방탄소년단',
#   'Permission to Dance',
#   'Butter / Permission to Dance',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['66',
#   '한동근',
#   '새벽에 걸려온 너의 전화는',
#   '미련을 말하는',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['67',
#   '폴킴',
#   '모든 날, 모든 순간 (Every day, Every Moment)',
#   "'키스 먼저 할까요?' OST Part.3",
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['68',
#   'aespa',
#   '도깨비불 (Illusion)',
#   'Girls - The 2nd Mini Album',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['69',
#   '볼빨간사춘기',
#   'Love story',
#   'Seoul',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['70',
#   '김호중',
#   '주마등',
#   'PANORAMA',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['71',
#   'The Kid LAROI',
#   'STAY',
#   'Stay',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['72',
#   'ITZY (있지)',
#   'SNEAKERS',
#   'CHECKMATE',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['73',
#   '탑현',
#   '사랑한다고 말해줘',
#   '사랑한다고 말해줘',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['74',
#   '경서',
#   '밤하늘의 별을(2020)',
#   '밤하늘의 별을(2020)',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['75',
#   '김호중',
#   '빛이 나는 사람',
#   '빛이 나는 사람',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['76',
#   'BIGBANG (빅뱅)',
#   '봄여름가을겨울 (Still Life)',
#   '봄여름가을겨울 (Still Life)',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['77',
#   '김호중',
#   '약속 [約束]',
#   'PANORAMA',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['78',
#   '김호중',
#   '친구',
#   'PANORAMA',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['79',
#   '김호중',
#   '슬픈등',
#   '인생은 뷰티풀: 비타돌체',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['80',
#   '윤미래',
#   'LAW (Prod. Czaer)',
#   '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['81',
#   '김호중',
#   'Brucia La Terra',
#   'PANORAMA',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['82',
#   '김호중',
#   'Champagne',
#   'PANORAMA',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['83',
#   '나연 (TWICE)',
#   'POP!',
#   'IM NAYEON',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['84',
#   '김호중',
#   'Love in Portofino',
#   'PANORAMA',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['85',
#   '21학번',
#   '스티커 사진',
#   '스티커 사진',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['86',
#   'Red Velvet (레드벨벳)',
#   'Feel My Rhythm',
#   '‘The ReVe Festival 2022 - Feel My Rhythm’',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['87',
#   '태연 (TAEYEON)',
#   'INVU',
#   'INVU - The 3rd Album',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['88',
#   '김호중',
#   '노래해요 (Duet with 최백호)',
#   'PANORAMA',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['89',
#   '(여자)아이들',
#   'MY BAG',
#   'I NEVER DIE',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['90',
#   '아이유',
#   'strawberry moon',
#   'strawberry moon',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['91',
#   '아이유',
#   '내 손을 잡아',
#   '최고의 사랑 OST Part.4',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['92',
#   'Justin Bieber',
#   'Off My Face',
#   'Justice (The Complete Edition)',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['93',
#   '이영현',
#   '그래서 그대는',
#   '그래서 그대는',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['94',
#   'NMIXX',
#   'DICE',
#   'ENTWURF',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['95',
#   '이무진',
#   '신호등',
#   '신호등',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['96',
#   'aespa',
#   'Next Level',
#   'Next Level',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['97',
#   '윤하 (YOUNHA)',
#   '오르트구름',
#   "YOUNHA 6th Album 'END THEORY'",
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['98',
#   '보라미유',
#   '통화연결음',
#   '통화연결음',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['99',
#   '아이유',
#   '드라마',
#   '조각집',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'],
#  ['100',
#   '김나영',
#   '못해',
#   '못해 (Re : WIND 4MEN Vol.02)',
#   '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t']]

# %%
def save_csv(chart_lst, filename):
    import csv
    with open(f'data/{filename}.csv', 'w') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['순위','가수','노래제목','앨범'])
        for idx in range(len(chart_lst)):
            writer.writerow([chart_lst[idx][0], chart_lst[idx][1],
                             chart_lst[idx][2],chart_lst[idx][3]])
    return print(f'{filename}.csv 파일로 저장 완료했습니다!')

# %%
save_csv(crawling(), '멜론 음원 순위')
# Out:
# 멜론 음원 순위.csv 파일로 저장 완료했습니다!

# %%
def main():
    crawling()
    save_csv(crawling(), '멜론 음원 순위')

# %%
if __name__ == '__main__':
    main()
# Out:
# 멜론 음원 순위.csv 파일로 저장 완료했습니다!

# %% [markdown]
# # 최종

# %%
def crawling():
    import requests
    from bs4 import BeautifulSoup
    request_headers = {'User-Agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 '
                   '(KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36')}
    response = requests.get('https://www.melon.com/chart/index.htm', headers = request_headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'lxml')
        song_infos1 = soup.select('tr[class=lst50]')
        song_infos2 = soup.select('tr[class=lst100]')
        song_infos = song_infos1 + song_infos2
        
        chart_lst = []
        
        for song_info in song_infos:
            info_lst = [] # 한 곡의 정보
            
            # 순위
            ranking = song_info.select('span.rank')[0].text # 'span.rank' / 'span[class=rank]' 다됨!!  / tag=span, class=rank(.) / id는(#)
            info_lst.append(ranking)
            # 가수
            singer = song_info.select('div.ellipsis.rank02 >a')[0].text
            info_lst.append(singer)
            # 노래 제목
            title = song_info.select('div.ellipsis.rank01 > span > a')[0].text
            info_lst.append(title)
            # 앨범
            album = song_info.select('div.ellipsis.rank03 > a')[0].text
            info_lst.append(album)
            # 좋아요 수
            like = song_info.select('span.cnt > span.none')[0].text
            info_lst.append(like)
            
            chart_lst.append(info_lst)
    return chart_lst
            
    
    
def save_csv(chart_lst, filename):
    import csv
    with open(f'data/{filename}.csv', 'w') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['순위','가수','노래제목','앨범'])
        for idx in range(len(chart_lst)):
            writer.writerow([chart_lst[idx][0], chart_lst[idx][1],
                             chart_lst[idx][2],chart_lst[idx][3]])
    return print(f'{filename}.csv 파일로 저장 완료했습니다!')



def main():
    crawling()
    save_csv(crawling(), '멜론 음원 순위')
    

if __name__ == '__main__':
    main()
# Out:
# 멜론 음원 순위.csv 파일로 저장 완료했습니다!
